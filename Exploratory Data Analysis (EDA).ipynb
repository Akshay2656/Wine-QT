# %% [markdown]
# # EDA - Exploratory Data Analysis in Python

# %% [markdown]
# ## Explorarory Data Analysis (EDA) is a important step in data analysis which focuese on understanding patterns, trends and relationships through statistical tools and visualizations.

# %% [markdown]
# ## Step 1: Importing Required Libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wr 
wr.filterwarnings('ignore')

# %% [markdown]
# ## Step 2: Reading dataset

# %%
df = pd.read_csv("C:\\Users\\akshay\\Downloads\\WineQT.csv")

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %% [markdown]
# ## Step 3: Analyzing the data

# %% [markdown]
# ### df.shape:
# #### This function is used to understand the number of rows and columns in the dataset. This give an overview of the dataset's size

# %%
df.shape
# Out:
# (1143, 13)

# %% [markdown]
# ### df.info():
# #### This function helps us to understand the dataset by showing the number of records in each cloumn, type of data , whether any values are missiong and how much memory the dataset uses

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %% [markdown]
# ### df.describe():
# #### This method gives a statistical summary of the dataframe showing valuse like count, mean, standard deviation, minium and quartiles for each numnerical column

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %% [markdown]
# ## Step 4: Checking Missing values

# %% [markdown]
# ### df.isnull().sum():
# #### This checks for missing values in each colums and returns the total number of null values per column helping us to identify any gaps in our data

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %% [markdown]
# ## Step 5: Checking for the duplicate values

# %%
df.nunique()
# Out:
# fixed acidity             91
# volatile acidity         135
# citric acid               77
# residual sugar            80
# chlorides                131
# free sulfur dioxide       53
# total sulfur dioxide     138
# density                  388
# pH                        87
# sulphates                 89
# alcohol                   61
# quality                    6
# Id                      1143
# dtype: int64

# %% [markdown]
# ## Step 6: Univariant Analysis

# %% [markdown]
# ### In Univariant analysis plotting the right charts can helps us to better understand the data making the data visulaization so important

# %% [markdown]
# ### 1. Bar Plot evaluating the cout of the wine with its quality rate

# %%
quality_counts = df['quality'].value_counts()

plt.figure(figsize=(6,4))
plt.bar(quality_counts.index, quality_counts, color = 'black')
plt.title('Counts Plot of quality')
plt.xlabel('Quality')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Here this count plot graph shows the count of the wine with its quality rate

# %% [markdown]
# ### 2. Kernal density plot for understanding variance in the dataset

# %%
sns.set_style("darkgrid")
numerical_columns = df.select_dtypes(include = ['int64','float']).columns

plt.figure(figsize=(14, len(numerical_columns) *3))
for index, feature in enumerate(numerical_columns, 1):
    plt.subplot(len(numerical_columns), 2, index)
    sns.histplot(df[feature],kde=True)
    plt.title(f"{feature} | Skewness: {round(df[feature].skew(),2)}")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### The features in the dataset with a skewness of 0 shows a symmetrical distribution. If the skewness is 1 or above it suggests a positively skewed (right-skewed) distribution. In a right-skewed distribution the tail extends more to the right which shows the presence of extremely high values.

# %% [markdown]
# ## 3. Swarm plot for showing the outlier in the data set

# %%
plt.figure(figsize=(10,8))
sns.swarmplot(x = 'quality', y = 'alcohol', data = df, palette = 'viridis')
plt.title('Swarm plot for quality and alcohol')
plt.xlabel('Quality')
plt.ylabel('Alcohol')
plt.show()

# %% [markdown]
# ### This graph shows the swarm plot for the 'Quality' and 'Alcohol' columns. The higher point density in certain areas shows where most of the data points are concentrated. Points that are isolated and far from these clusters represent outliers highlighting uneven values in the dataset.

# %% [markdown]
# ## Step 7: Bivariant Analysis

# %% [markdown]
# ### In bivariant analysis two variables are analyzed together to identify patterns, dependencies or interactions between them. This method helps in understanding how changes in one variable might affect another

# %% [markdown]
# ### 1. Pair plot for showingg the distribution of the individual variable

# %%
sns.set_palette("Pastel1")

plt.figure(figsize=(10,6))
sns.pairplot(df)
plt.suptitle('Pair Plot for datafreame')
plt.show()

# %% [markdown]
# ### If the plot diagonal, histogram of kernal density plot hsows the distribution of the indivisual variables.
#
# ### If the scatter plot is in the lower triangle, it displays the repationship between the pair of the variable
#
# ### If the scatter plot above and below the diagonal are mirror images indicating symmetry.
#
# ### if the histogram plots are more centered , it represents the location of the peaks.
#
# ### Skewness is found by observing whether the histogram is symmetrical or skewed to the left or right

# %% [markdown]
# ## 2. Violin Plot for examining the relationship between alcohol and Quality.

# %%
df['quality'] = df['quality'].astype(str)

plt.figure(figsize=(10,8))

sns.violinplot(x = 'quality', y = 'alcohol', data = df)
plt.title("Voilin Plot for Qanlity and Alcohol")
plt.xlabel("Quality")
plt.ylabel("Alcohol")
plt.show()

# %% [markdown]
# ## For interpreting the Violin Plot:
# ### if the width is wider, it shows higher density suggesting more data points.
# ### Symmetrical plot shows a balanced distribution.
# ### Peak or bulge in the violin plot represnts most common value in distribution.
# ### Longere tails shows great variability.
# ### Median line is the middle line inside the viloin plot it helps in understanding central tendencies.

# %% [markdown]
# ## 3. Box plot for examining the relationship between alcohol and quality

# %%
sns.boxplot(x = 'quality', y = 'alcohol', data = df)
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %% [markdown]
# ### Box represent the IOR i.e. longer the box, greater the variability.
# #### Mean line in the box shows central tendency.
# #### Whiskers extend from box to the smallest and largest values withoin ta specific range
# #### Individual points beyond the whiskers represnts outliers.
# #### A compact box shows low variability while a streched box shows higher variability.

# %% [markdown]
# ## Step 8: Multivariant Analysis

# %% [markdown]
# ### It involves finding the interactions between three or more variables in dataset st the same time. This approach focuses to identify complex patterns, relationships and interactions which provides understanding of how multiple variable collectively behave and influence each other

# %% [markdown]
# ### Correlation matrix plot

# %%
plt.figure(figsize=(15,10))

sns.heatmap(df.corr(), annot = True, fmt = '.2f', cmap = 'Pastel2', linewidths = 2)
plt.title('Correlation matrix')
plt.show()

# %% [markdown]
# ### Values close to +1 shows strong positive correlation, -1 shows a strong negative correlation and 0 suggest no linear correlation
# #### Darker colors sigify strong correlation, while light colors represnts weaker correlations.
# #### Positive correlation variable move in same direction. As one increases, the other also increases.
# #### Negative correlation variablle move in opposite directioins. AN increase in one variable is associated with a decrease in the other.
